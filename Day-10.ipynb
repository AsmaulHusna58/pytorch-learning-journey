# %% [markdown]
# <img src = "Video-10/Screenshot 2026-09-15 135607.png">

# %% [markdown]
# <img src = "Video-10/Screenshot 2026-09-15 140143.png">

# %% [markdown]
# <img src = "Video-10/Screenshot 2026-09-15 140334.png">
